# %%
import pandas as pd
import geopandas as gpd
import shapely.geometry as Point
# %matplotlib inline

# %%
selected_states = gpd.read_file("Google StreetView Road Segments/Google StreetView Road Segments/merged_shapefile_proj_spatial.shp")
polygons_within = gpd.read_file("GSV polygons/GSV polygons/polygons.shp")

# %%
polygons_within.head()
# Out:
#                                              Name Descriptio  \
# 0        2023 Swarms_NG_10300ab-NG.0_10300ab-NG.0       None
# 1  2023 Swarms_NG_10300ab-NG.1000_10300ab-NG.1000       None
# 2  2023 Swarms_NG_10300ab-NG.1001_10300ab-NG.1001       None
# 3  2023 Swarms_NG_10300ab-NG.1002_10300ab-NG.1002       None
# 4  2023 Swarms_NG_10300ab-NG.1004_10300ab-NG.1004       None
#
#                                             filename  \
# 0      2023 Swarms_NG_10300ab-NG.0_10300ab-NG.0_zone
# 1  2023 Swarms_NG_10300ab-NG.1000_10300ab-NG.1000...
# 2  2023 Swarms_NG_10300ab-NG.1001_10300ab-NG.1001...
# 3  2023 Swarms_NG_10300ab-NG.1002_10300ab-NG.1002...
# 4  2023 Swarms_NG_10300ab-NG.1004_10300ab-NG.1004...
#
#                                             geometry
# 0  POLYGON ((4.08999 8.15702, 4.08999 8.13521, 4....
# 1  POLYGON ((7.91571 13.21304, 7.93749 13.21236, ...
# 2  POLYGON ((7.78514 12.53174, 7.80689 12.53111, ...
# 3  POLYGON ((6.17391 5.00998, 6.19513 5.00978, 6....
# ...

# %%
selected_sselected_statestates.shape
# Out:
# (315464, 21)

# %%
selected_states.head()
# Out:
#    Join_Count  TARGET_FID    Name Descriptio       Length  OBJECTID  \
# 0           1           0  Plan-0       None   559.581329        19
# 1           1           1  Plan-0       None   122.850981        19
# 2           1           2  Plan-0       None   383.538965        19
# 3           1           3  Plan-0       None   856.214509        19
# 4           1           4  Plan-0       None  1502.809994        19
#
#                                                  id    geometry_t state_code  \
# 0  sv_boundary_states.fid-65d4c550_169d91acef3_3f7c  MULTIPOLYGON         OY
# 1  sv_boundary_states.fid-65d4c550_169d91acef3_3f7c  MULTIPOLYGON         OY
# 2  sv_boundary_states.fid-65d4c550_169d91acef3_3f7c  MULTIPOLYGON         OY
# 3  sv_boundary_states.fid-65d4c550_169d91acef3_3f7c  MULTIPOLYGON         OY
# 4  sv_boundary_states.fid-65d4c550_169d91acef3_3f7c  MULTIPOLYGON         OY
#
#   state_name  ...                             global_id     source geographic  \
# ...

# %%
selected_states.shape
# Out:
# (315464, 21)

# %%
polygons_within.shape
# Out:
# (1232, 4)

# %%
selected_states.crs
# Out:
# <Projected CRS: PROJCS["WGS_1984_UTM_Zone_31N",GEOGCS["WGS 84",DAT ...>
# Name: WGS_1984_UTM_Zone_31N
# Axis Info [cartesian]:
# - [east]: Easting (Meter)
# - [north]: Northing (Meter)
# Area of Use:
# - undefined
# Coordinate Operation:
# - name: UTM zone 31N
# - method: Transverse Mercator
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
polygons_within.crs
# Out:
# <Geographic 2D CRS: GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84" ...>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - lon[east]: Longitude (Degree)
# - lat[north]: Latitude (Degree)
# Area of Use:
# - undefined
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
polygons_within.to_crs(selected_states.crs, inplace=True)

# %%
polygons_within.crs
# Out:
# <Projected CRS: PROJCS["WGS_1984_UTM_Zone_31N",GEOGCS["WGS 84",DAT ...>
# Name: WGS_1984_UTM_Zone_31N
# Axis Info [cartesian]:
# - [east]: Easting (Meter)
# - [north]: Northing (Meter)
# Area of Use:
# - undefined
# Coordinate Operation:
# - name: UTM zone 31N
# - method: Transverse Mercator
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
road_spatial_join = gpd.sjoin(selected_states, polygons_within, how='inner', predicate='within')

# %%
road_spatial_join
# Out:
#         Join_Count  TARGET_FID Name_left Descriptio_left       Length  \
# 0                1           0    Plan-0            None   559.581329
# 1                1           1    Plan-0            None   122.850981
# 2                1           2    Plan-0            None   383.538965
# 3                1           3    Plan-0            None   856.214509
# 4                1           4    Plan-0            None  1502.809994
# ...            ...         ...       ...             ...          ...
# 315459           1      315459    Plan-0            None    23.359189
# 315460           1      315460    Plan-0            None    58.445202
# 315461           1      315461    Plan-0            None   191.761649
# 315462           1      315462    Plan-0            None    65.124536
# 315463           1      315463    Plan-0            None   283.948598
#
#         OBJECTID                                                id  \
# ...

# %%
Output_name = 'Spatially_joined_road.shp'

# %%
road_spatial_join.to_file(Output_name, driver='ESRI Shapefile')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8632\45860614.py:1: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   road_spatial_join.to_file(Output_name, driver='ESRI Shapefile')

# %%
road_spatial_join.shape
# Out:
# (308907, 25)
